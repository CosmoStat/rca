# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from rca import RCA, quickload
from rca import utils

np.random.seed(1331)
# Out:
# WARNING: Using pyFFTW "monkey patch" for scipy.fftpack
# /Users/mschmitz/anaconda/lib/python2.7/site-packages/skimage/measure/_marching_cubes_lewiner.py:16: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from . import _marching_cubes_lewiner_cy
# /Users/mschmitz/anaconda/lib/python2.7/site-packages/skimage/measure/_marching_cubes_classic.py:4: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from . import _marching_cubes_classic_cy
# /Users/mschmitz/anaconda/lib/python2.7/site-packages/skimage/measure/_label.py:1: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from ._ccomp import label_cython as clabel
# /Users/mschmitz/anaconda/lib/python2.7/site-packages/skimage/measure/pnpoly.py:1: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from ._pnpoly import _grid_points_in_poly, _points_in_poly

# %% [markdown]
# Define a plotting function for visual inspection:

# %%
def plot_func(im, wind=False, cmap='gist_stern', title=''):
    if not wind:
        plt.imshow(im, cmap=cmap, interpolation='Nearest')
    else:
        vmin, vmax = wind
        plt.imshow(im, cmap=cmap, interpolation='Nearest', vmin=vmin, vmax=vmax)
    if title:
        plt.title(title)
    plt.colorbar()
    plt.xticks([])
    plt.yticks([])
    plt.show()
    plt.close()

# %% [markdown]
# # Load and prepare data

# %% [markdown]
# Load star catalog; `stars.npy` contains 323 stars from one of the two ACS chips in exposure `jb5d20b7_drz_1`, and `pos.npy` their respective (image) positions.

# %%
starcat = np.load('stars.npy')
pos = np.load('pos.npy')
print starcat.shape, pos.shape
# Out:
# (323, 41, 41) (323, 2)

# %% [markdown]
# Stars are fresh from `SExtractor` so we need to pass on the masks to RCA; for visual inspection, we also replace them with 0's in the data.

# %%
mask = np.ones(starcat.shape)
mask[starcat<-1e10] = 0
starcat[starcat<-1e10] = 0
for j in np.random.choice(starcat.shape[0], 5, False):
    plot_func(starcat[j])
    print j
# Out:
# 170
# 230
# 9
# 271
# 33

# %% [markdown]
# Split them into "train" and "test" stars - the latter won't be used to fit the model:

# %%
test_idx = np.random.choice(starcat.shape[0], 23, False)
train_idx = list(set(range(starcat.shape[0])) - set(test_idx))

train_stars, train_pos = starcat[train_idx], pos[train_idx]
test_stars, test_pos = starcat[test_idx], pos[test_idx]
train_mask = mask[train_idx]

# %% [markdown]
# # Run RCA

# %% [markdown]
# Remember RCA expects the stars (and pixel weights) to be in $(p\times p\times n_\rm{stars})$ format, so convert them (and their masks):

# %%
train_stars = utils.rca_format(train_stars)
train_mask = utils.rca_format(train_mask)

# %% [markdown]
# ## No super-resolution
#
# We need to provide a very crude first guess of the PSF size (only used for centroid, and thus intrapixel shift, estimation). HST ACS has a pixel scale of about 0.049'', and an FWHM of around 0.9'', or about 2 pixels, so let us provide RCA's `fit` method with `psf_size=2` (FWHM is the default convention).
#
# Run without superresolution first:

# %%
n_comp = 4
rca_fitter = RCA(n_comp, verbose=True)

S, A = rca_fitter.fit(train_stars, train_pos, train_mask, psf_size=2.)
rca_fitter.quicksave('fitted_model')
# Out:
# Running basic initialization tasks...
# /Users/mschmitz/anaconda/lib/python2.7/site-packages/modopt/signal/wavelet.py:160: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   fake_data[list(zip(data_shape // 2))] = 1
# ... Done.
# Constructing graph constraint...
#  > power max =  3.1459960292017133
#  > selected e: 0.244142522739	selected a: 1.99	 chosen index: 4/5
#  > selected e: 0.876396831976	selected a: 0.340854253267	 chosen index: 4/5
#  > selected e: 1.66046407772	selected a: 0.032423227174	 chosen index: 3/5
#  > selected e: 1.66046407772	selected a: 0.340854253267	 chosen index: 1/5
# ... Done.
# /Users/mschmitz/anaconda/lib/python2.7/site-packages/modopt/base/types.py:137: FutureWarning: Conversion of the second argument of issubdtype from `'float'` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype('float').type`.
#   (not np.issubdtype(val.dtype, dtype))):
# WARNING: Making input data immutable.
# 100% (200 of 200) |######################| Elapsed Time: 0:01:05 Time:  0:01:05
#  - Converged!
# 100% (400 of 400) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  - Converged!
# 100% (200 of 200) |######################| Elapsed Time: 0:00:56 Time:  0:00:56
#  - Converged!

# %% [markdown]
# Look at learned eigenPSFs:

# %%
eigenPSFs = utils.reg_format(S)
for epsf in eigenPSFs:
    plot_func(np.abs(epsf))

# %% [markdown]
# To compare with test stars, we first need to compute their shifts and fluxes, all of which can be done using methods from `utils`:

# %%
cents = []
for star in test_stars:
    cents += [utils.CentroidEstimator(star)]
test_shifts = np.array([ce.return_shifts() for ce in cents])
fluxes = utils.flux_estimate_stack(utils.rca_format(test_stars),rad=4)

# %% [markdown]
# And estimate PSF model at test star positions. Note the `apply_degradation` and `shifts` are set so we reshift the PSF model for comparison with the stars:

# %%
reconstructed_stars = rca_fitter.estimate_psf(test_pos, apply_degradation=True, shifts=test_shifts, flux=fluxes)

# %% [markdown]
# Look at a few examples:

# %%
for j in np.random.choice(test_stars.shape[0], 3, False):
    rec_star = reconstructed_stars[j]
    wind = (min(np.min(test_stars[j]),np.min(rec_star)),
            max(np.max(test_stars[j]),np.max(rec_star)))
    plot_func(test_stars[j], title='Test star', wind=wind)
    plot_func(rec_star, title='PSF model', wind=wind)
    plot_func(np.abs(test_stars[j]-rec_star), title='residual', wind=wind)
    print j
# Out:
# 10
# 2
# 15

# %% [markdown]
# And compute average normalized Mean Square Error:

# %%
MSE = np.mean((np.linalg.norm(test_stars - reconstructed_stars, axis=(1,2)) /
              np.linalg.norm(test_stars, axis=(1,2))**2))
print MSE
# Out:
# 0.04271503973917776

# %% [markdown]
# ## Super-resolution
#
# Rerun RCA, but oversample PSF model:

# %%
rca_sr = RCA(n_comp, upfact=2, verbose=True)

sr_S, sr_A = rca_sr.fit(train_stars, train_pos, train_mask, psf_size=2.)

rca_sr.quicksave('sr_fitted_model')

sr_eigenPSFs = utils.reg_format(sr_S)
for epsf in sr_eigenPSFs:
    plot_func(epsf)
# Out:
# Running basic initialization tasks...
# ... Done.
# Constructing graph constraint...
#  > power max =  3.1459960292017133
#  > selected e: 0.244142522739	selected a: 1.99	 chosen index: 4/5
#  > selected e: 0.876396831976	selected a: 0.340854253267	 chosen index: 4/5
#  > selected e: 1.66046407772	selected a: 0.032423227174	 chosen index: 3/5
#  > selected e: 1.66046407772	selected a: 0.340854253267	 chosen index: 1/5
# ... Done.
# WARNING: Making input data immutable.
# 100% (200 of 200) |######################| Elapsed Time: 0:03:14 Time:  0:03:14
# 100% (400 of 400) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#  - Converged!
# 100% (200 of 200) |######################| Elapsed Time: 0:03:14 Time:  0:03:14

# %% [markdown]
# To compute residuals, we now also need to resample them at the observation's pixel scale:

# %%
PSFs = rca_sr.estimate_psf(test_pos)
sr_reconstructed_stars = rca_sr.estimate_psf(test_pos, apply_degradation=True, shifts=test_shifts, flux=fluxes)

print PSFs.shape
print sr_reconstructed_stars.shape

for j in np.random.choice(test_stars.shape[0], 3, False):
    rec_star = sr_reconstructed_stars[j]
    wind = (min(np.min(test_stars[j]),np.min(rec_star)),
            max(np.max(test_stars[j]),np.max(rec_star)))
    plot_func(PSFs[j], title='PSF model')
    plot_func(test_stars[j], title='Test star', wind=wind)
    plot_func(rec_star, title='Reconstructed star', wind=wind)
    plot_func(np.abs(test_stars[j]-rec_star), title='residual', wind=wind)
    print j
# Out:
# (23, 82, 82)
# (23, 41, 41)
# 5
# 17
# 21

# %%
MSE = np.mean((np.linalg.norm(test_stars - sr_reconstructed_stars, axis=(1,2)) /
              np.linalg.norm(test_stars, axis=(1,2))**2))
print MSE
# Out:
# 0.04323619241744437
